# %%
# %pylab notebook
import os, sys, importlib
sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation')
import pandas as pd, numpy as np, scipy as scp , seaborn as sns
import hts_fitting as hts, default_figure_style as dfs, hts_dosecalculations as dose, hts_fitfunctions as ff, hts_misc as misc

for lib in [hts, ff, dfs, misc]:
    importlib.reload(lib)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Get data for the suspicious row

# %%
i = 681 #489, [680, 681, 682],

cols = [0, 3, 4, 5, 6, 7, 15, 16, 17, 18]

names = [
    'tapeid',     # tape sample name
    'sname',      # sheet name in spreadsheet with beam current data
    't0Beam',     # start time of interval for beam current evaluation
    't1Beam',     # stop time of interval for beam current evaluation
    't0Offset',   # start time of interval for beam current offset evaluation
    't1Offset',    # stop time of interval for beam current offset evaluation
    'f0',
    'foff',
    'fon',
    'feq'    
]
dfrow = pd.read_excel(dfs.master, usecols=cols, names=names, skiprows=1).iloc[i-3]

# %% [markdown]
# ## Check the IVs

# %%
fpaths[1]
# Out:
# '../data/Ic/f37/Ic_2024-05-12_18-20-34239698_f37-150keV-325nA-20K.txt'

# %%
path = '../data/Ic/{0}/'.format(dfrow.tapeid)
fpaths = [path+f for f in [dfrow.f0, dfrow.fon, dfrow.foff, dfrow.feq]]
hts.showcaseIVs(fpaths)
# Out:
# <img src="data:image/png;base64,..." width="900">
# IntText(value=1, description='IV#:')
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py:93: RuntimeWarning: invalid value encountered in log
#   current, voltage = np.log(current), np.log(voltage)
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitfunctions.py:31: RuntimeWarning: invalid value encountered in power
#   return 2e-7*(i/ic)**n
# /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# ## Check the beam current intervals

# %%
ibpath = '../data/flux/{0}.xlsx'.format(dfrow.tapeid)
sname = '{}'.format(dfrow.sname)

dose.plotBeamCurrentWithMeasurements([fpaths[1]], ibpath, sname)
# Out:
# dose::loadBeamCurrent raised:  <class 'datetime.time'> is not convertible to datetime, at position 0
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 ibpath = '../data/flux/{0}.xlsx'.format(dfrow.tapeid)
#       2 sname = '{}'.format(dfrow.sname)
# ----> 3 dose.plotBeamCurrentWithMeasurements([fpaths[1]], ibpath, sname)
#
# File ~/Documents/code/hts-irradiation/hts_dosecalculations.py:70, in plotBeamCurrentWithMeasurements(fpaths, ibpath, sname, fig)
#      68 data = loadBeamCurrent(ibpath, sname=sname)
#      69 if fig is None: fig, ax = plt.subplots()
# ---> 70 fig, axrt, axdt = plotBeamCurrent(data, fig=fig)
#      71 starts, ends = getMeasurementStartTime(fpaths, year='2024')
#      72 for t0, t1 in zip(starts, ends):
#
# File ~/Documents/code/hts-irradiation/hts_dosecalculations.py:50, in plotBeamCurrent(data, fig, color)
#      47 else:
#      48     axdt = fig.gca()
# ---> 50 axdt.plot(data.time_datetime, data.ibeam_nA, linestyle='None')
#      51 lower, upper = data.time_datetime.min(), data.time_datetime.max()
#      52 print(lower, upper)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/lines.py:1028, in Line2D.get_path(self)
#    1026 """Return the `~matplotlib.path.Path` associated with this line."""
#    1027 if self._invalidy or self._invalidx:
# -> 1028     self.recache()
#    1029 return self._path
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/lines.py:659, in Line2D.recache(self, always)
#     657 if always or self._invalidx:
#     658     xconv = self.convert_xunits(self._xorig)
# --> 659     x = _to_unmasked_float_array(xconv).ravel()
#     660 else:
#     661     x = self._x
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1340, in _to_unmasked_float_array(x)
#    1338     return np.ma.asarray(x, float).filled(np.nan)
#    1339 else:
# -> 1340     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'datetime.time'

# %%
data = dose.loadBeamCurrent('../data/flux/{0}.xlsx'.format(dfrow.tapeid), sname='{}'.format(dfrow.sname))
x, y = data.time_s, data.ibeam_nA

ocut = (dfrow.t0Offset <= data.time_s) & (data.time_s <= dfrow.t1Offset)
mcut = (dfrow.t0Beam <= data.time_s) & (data.time_s <= dfrow.t1Beam)
xo, yo = data.time_s[ocut], data.ibeam_nA[ocut]
xm, ym = data.time_s[mcut], data.ibeam_nA[mcut]

start, stop = dose.getMeasurementStartTime([fpaths[0]])

fig, ax = plt.subplots()
ax.plot(x, y, color='k')
ax.plot(xo, yo, color='b', marker='+')
ax.plot(xm, ym, color='b', marker='+')
ax.axvspan(start, stop, alpha=.2, color='b')

ax.set_xlim(np.min([dfrow.t0Beam, dfrow.t0Offset]), np.max([dfrow.t1Beam, dfrow.t1Offset]))
ax.set_ylim(-10, np.max(y))
ax.set_xlabel('Time relative [s]')
ax.set_ylabel('Beam Current [nA]')

print(np.mean(ym), np.std(ym))
# Out:
# dose::loadBeamCurrent raised:  <class 'datetime.time'> is not convertible to datetime, at position 0
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 15
#      13 ax.plot(xo, yo, color='b', marker='+')
#      14 ax.plot(xm, ym, color='b', marker='+')
# ---> 15 ax.axvspan(start, stop, alpha=.2, color='b')
#      17 ax.set_xlim(np.min([dfrow.t0Beam, dfrow.t0Offset]), np.max([dfrow.t1Beam, dfrow.t1Offset]))
#      18 ax.set_ylim(-10, np.max(y))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1026, in Axes.axvspan(self, xmin, xmax, ymin, ymax, **kwargs)
#    1023 (xmin, xmax), = self._process_unit_info([("x", [xmin, xmax])], kwargs)
#    1025 verts = [(xmin, ymin), (xmin, ymax), (xmax, ymax), (xmax, ymin)]
# -> 1026 p = mpatches.Polygon(verts, **kwargs)
#    1027 p.set_transform(self.get_xaxis_transform(which="grid"))
#    1028 p.get_path()._interpolation_steps = 100
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/patches.py:1095, in Polygon.__init__(self, xy, closed, **kwargs)
#    1093 super().__init__(**kwargs)
#    1094 self._closed = closed
# -> 1095 self.set_xy(xy)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/patches.py:1147, in Polygon.set_xy(self, xy)
#    1131 def set_xy(self, xy):
#    1132     """
#    1133     Set the vertices of the polygon.
#    1134
#    (...)
#    1145     ``CLOSEPOLY`` vertex, and add it ourselves.
#    1146     """
# -> 1147     xy = np.asarray(xy)
#    1148     nverts, _ = xy.shape
#    1149     if self._closed:
#    1150         # if the first and last vertex are the "same", then we assume that
#    1151         # the user explicitly passed the CLOSEPOLY vertex. Otherwise, we
#    1152         # have to append one since the last vertex will be "ignored" by
#    1153         # Path
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (4, 2) + inhomogeneous part.

# %%
# %debug
# Out:
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/io/common.py(859)get_handle()
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py(1661)_make_engine()
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py(1407)__init__()
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py(577)_read()
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py(912)read_csv()
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# ipdb> up
# > /Users/alexisdevitre/Documents/code/hts-irradiation/hts_dosecalculations.py(21)getMeasurementStartTime()
#      19     starttimes, endtimes = [], []
#      20     for path in fpaths:
# ---> 21         df = pd.read_csv(path, usecols=[0], names=['date'], dtype={'date': 'str'}, delim_whitespace=True, skiprows=2)
#      22         startdate = year+df['date'].iloc[0][4:]
#      23         enddate = year+df['date'].iloc[-1][4:]
#
# ipdb> up
# > /var/folders/jl/4_5mv35x3wb9cccz5qcc6vmc0000gn/T/ipykernel_9225/103735263.py(9)<module>()
#       7 xm, ym = data.time_s[mcut], data.ibeam_nA[mcut]
#       8
# ----> 9 start, stop = dose.getMeasurementStartTime(fpaths[0])
#      10
#      11 fig, ax = plt.subplots()
#
# ipdb> down
# > /Users/alexisdevitre/Documents/code/hts-irradiation/hts_dosecalculations.py(21)getMeasurementStartTime()
#      19     starttimes, endtimes = [], []
#      20     for path in fpaths:
# ---> 21         df = pd.read_csv(path, usecols=[0], names=['date'], dtype={'date': 'str'}, delim_whitespace=True, skiprows=2)
#      22         startdate = year+df['date'].iloc[0][4:]
#      23         enddate = year+df['date'].iloc[-1][4:]
#
# ipdb> df
# *** NameError: name 'df' is not defined
# ipdb> exit
