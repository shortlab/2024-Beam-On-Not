# %%
# %pylab notebook
import os, sys, pandas as pd, numpy as np
sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation')
import hts_fitting as hts
import default_figure_style

outputDirectory = '../figures/raw/'
parentDirectory = '../data/Ic/f23/'
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
files = [
    'Ic_2023-10-31_23-06-11441040_f23-BeamOn3-20K-a.txt',
    'Ic_2023-10-31_23-12-11310373_f23-BeamOn3-20K-b.txt',
    'Ic_2023-11-01_10-29-29487750_f23-afterIrradiation-20K.txt',
    'Ic_2023-10-31_23-28-08056169_f23-afterIrradiation-32K.txt'
]

params = [
    {'label': 'Beam Off (before)',         'mfc': 'None', 'mec': 'k', 'marker': 'o', 'markersize': 8,  'alpha': .5, 'markeredgewidth': 1},
    {'label': 'Beam On (1.2 MeV x 30 nA)', 'mfc': 'b',    'mec': 'b', 'marker': 's', 'markersize': 8,  'alpha': 1,  'markeredgewidth': 1},
    {'label': 'Beam Off (after)',          'mfc': 'k',    'mec': 'k', 'marker': '+', 'markersize': 10, 'alpha': 1,  'markeredgewidth': 2},
    {'label': 'Beam Off (T = 31.9 K)',     'mfc': 'None', 'mec': 'b', 'marker': 'x', 'markersize': 8,  'alpha': 1,  'markeredgewidth': 1}
]

fig, ax = plt.subplots(1, 2, sharex=True, figsize=(10, 5))

for f, p in zip(files, params):
    
    data = pd.read_csv(parentDirectory+f, skiprows=1, delim_whitespace=True)
    ic, n, current, voltage, chisq, pcov = hts.fitIcMeasurement(parentDirectory+f, function='powerLaw')    
    ax[0].loglog(current, voltage*1e6, linestyle='None', **p)
    ax[1].semilogx(data.iHTS_A[::3], data.tHTS_K[::3], linestyle='None', **p)

ax[0].legend(loc='upper left')
ax[0].set_xlim(1e-2, 1e1)
ax[0].set_ylim(1e-4, 1e2)
ax[1].set_ylim(18, 34)
ax[1].set_yticks([18, 20, 22, 24, 26, 28, 30, 32, 34])
ax[0].set_ylabel('Voltage [uV]')
#ax[1].set_xlabel('$\mathrm{I_{op}}$: Transport Current [A]')
ax[1].set_ylabel('Temperature [K]') 
fig.text(0.5, 0.05, '$\mathrm{I_{op}}$: Transport Current [A]', ha='center', va='center', fontweight='bold')

plt.tight_layout(rect=[0, 0.05, 1, 1])


ax[0].set_rasterized(True)
ax[1].set_rasterized(True)
plt.savefig(outputDirectory+'figure05.svg')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py:58: RuntimeWarning: invalid value encountered in log
#   current, voltage = np.log(current), np.log(voltage)
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py:58: RuntimeWarning: invalid value encountered in log
#   current, voltage = np.log(current), np.log(voltage)
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py:58: RuntimeWarning: invalid value encountered in log
#   current, voltage = np.log(current), np.log(voltage)
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py:58: RuntimeWarning: invalid value encountered in log
#   current, voltage = np.log(current), np.log(voltage)

# %%
path = '../data/Ic/f23/'
fname = [
    'Ic_2023-10-27_06-55-39927079_f20-BeamOn13-800keV45nA20K-a.txt',
    'Ic_2023-10-27_06-57-06325418_f20-BeamOn13-800keV45nA20K-b.txt',
    'Ic_2023-10-27_07-16-17924151_f20-BeamOn13-800keV45nA20K-d.txt'
]

fname = [
    'Ic_2023-10-27_07-36-18535093_f20-BeamOn14-2400keV15nA20K-a.txt',
    'Ic_2023-10-27_07-38-01688915_f20-BeamOn14-2400keV15nA20K-b.txt',
    'Ic_2023-10-27_07-46-39107329_f20-BeamOn14-2400keV15nA20K-d.txt'
]



fname = [
    'Ic_2023-12-14_17-15-21157036_f34-800keV-0nA-20K.txt',
    'Ic_2023-12-14_17-15-47369317_f34-800keV-44nA-20K.txt',
    'Ic_2023-12-14_17-30-03166660_f34_tempmatch-33p6K.txt'
]

fname = [
    ,
    'Ic_2023-12-14_17-59-35333993_f34_2400keV-15nA-20.txt',
    'Ic_2023-12-14_18-06-50435666_f34_2400keV-0nA-36p6K.txt'
]


#path = '/Users/alexisdevitre/Dropbox (MIT)/2020 PhD/Research/Samples/Coated conductors/FFJ/2023-10_f23/Ic/'
#fname = [
#    'Ic_2023-10-31_23-06-46822973_f23-BeamOn3-20K-b.txt',
#    'Ic_2023-10-31_23-19-56027769_f23-afterlastbeamon_30K_d.txt',
#    'Ic_2023-10-31_23-20-43466291_f23-afterlastbeamon_30K_d.txt',
#    'Ic_2023-10-31_23-21-58476671_f23-afterlastbeamon_30K_d.txt',
#    'Ic_2023-10-31_23-26-01870477_f23-afterlastbeamon_32K_d.txt',
#    'Ic_2023-10-31_23-28-08056169_f23-afterlastbeamon_32K_d.txt'
#]

fpaths = [path+f for f in os.listdir(path) if f in fname]

hts.showcaseIVs(fpaths, style='powerLaw', vMax=5e-6)
# Out:
# <img src="data:image/png;base64,..." width="900">
# IntText(value=1, description='IV#:')
# list index out of range
