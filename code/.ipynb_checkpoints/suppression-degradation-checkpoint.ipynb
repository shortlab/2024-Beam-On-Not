# %% [markdown]
# # Interpolation of REBCO layer temperature from Critical Current measured during irradiation
#
# Here we plot all the critical temperature vs temperature calibrations used to estimate the temperature of REBCO during irradiation. On each plot, we overlay the "beam off IV" for each of the "beam on events" where we use the calibration as evidence that the calibration has not changed.

# %%
# %pylab notebook
import sys, os
import importlib
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import seaborn as sns

sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation')
import hts_fitting as hts, hts_fitfunctions as ff
importlib.reload(hts)
importlib.reload(ff)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <module 'hts_fitfunctions' from '/Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitfunctions.py'>

# %%
#fig, ax = plt.subplots()

path = '/Users/alexisdevitre/Desktop/IcT/f37/'
fpaths = [path+f for f in os.listdir(path) if f[:2]=='Tc']
fpath=fpaths[0]
#tvr = hts.readTV(fpath)
#tvs = tvr.rolling(10).mean()
#ax.plot(tvr.sampleT, tvr.voltage*1e6, marker='+', linestyle='None', color='k')
#ax.plot(tvs.sampleT, tvs.voltage*1e6, marker='+', linestyle='None', color='b')


hts.fitTcMeasurement(fpath, wsz=20, vb=True)
# Out:
# <img src="data:image/png;base64,..." width="900">
# 78.72715339553396

# %%
hts.getIcT(ictfpath, vb=False)
# Out:
# readIV raised:  [Errno 21] Is a directory: '/'
# / cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  U not found.
# U cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  s not found.
# s cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  e not found.
# e cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  r not found.
# r cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  s not found.
# s cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  [Errno 21] Is a directory: '/'
# / cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  a not found.
# a cannot access local variable 'temperature' where it is not associated with a value
# ...

# %%
fig, ax = plt.subplots()

path = '/Users/alexisdevitre/Desktop/IcT/f37/'
tcfpaths = [path+f for f in os.listdir(path) if (f[:2] == 'Tc')&(f != '.DS_Store')]
tcs = []
for tcfpath in tcfpaths:
    tcs.append(hts.fitTcMeasurement(tcfpath, wsz=20))
np.array(tcs)
    

ictpaths = [path+ict+'/' for ict in ['0e20pm2', '6e20pm2', 'after150keVSet', 'after2400keVSet', 'before150keVSet']]

for ictpath, tc, m in zip(ictpaths, tcs, ['*', '+', 's', 'o', 'x']):
    ictfpath = [ictpath+f for f in os.listdir(ictpath) if (f != '.DS_Store')]
    _, _, ic, temperature, _ = hts.getIcT(ictfpath, vb=False)
    ic, temperature = np.array(ic), np.array(temperature)
    ic20K = np.mean(ic[(19 < temperature) & (temperature < 21)])
    #ax.plot(ic/ic20K, temperature/tc, linestyle='None', marker=m, color='b', label=ictpath.split('/')[-2])
    ax.plot(temperature, ic/ic20K, linestyle='None', marker=m, color='b', label=ictpath.split('/')[-2])
    
    print(tc, ic20K)

#ax.set_xlabel('Temperature / Tc')
ax.set_xlabel('Temperature [k]')
ax.set_ylabel('Ic / Ic$^{20\,K}$')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">
# /Users/alexisdevitre/Documents/code/hts-irradiation/hts_f

fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)
ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

fnames = [
    'Ic_2024-02-09_14-08-27521298_f29-6e20pm2-1200keV-0nA-20k.txt'
]
path, tHTS, ics = '../data/Ic/{}/'.format(tape), [], []
for fpath in [path+f for f in fnames]:
    try:
        ic, _, _, _, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function=hts.powerLaw, vMax=5e-6, vb=False)
        _, _, temperature = hts.readIV(fpath)
        tHTS.append(np.nanmean(temperature[0][-10:]))
        ics.append(ic)
    except Exception as e:
        pass
ax.plot(ics, tHTS, marker='o', color='k', linestyle='None')


ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 7)
ax.set_ylim(0, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-4.50305291e-02  9.45967313e-01 -1.15648100e+01  6.76477214e+01] 7.134670231425777 7.134670231425777

# %%
tape, interpolation = 'f29', 'after800keV'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(2, 5)
ax.set_ylim(0, 40)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-8.16713658e-03  5.53540595e-01 -1.11134431e+01  5.85838018e+01] 2.7510393342254282 4.386766910442701

# %%
tape, interpolation = 'f29', 'after2400keV'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(2, 5)
ax.set_ylim(0, 40)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [ 0.10292205 -0.34163425 -8.87961175 54.92738009] 2.2988728881138933 4.1049993294418545

# %%
tape, interpolation = 'f29', 'before800keV'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 15)
ax.set_ylim(0, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# /Users/alexisdevitre/Desktop/IcT/f29/before800keV/Ic_2024-02-26_14-07-03948994_f29-6e20pm2-anneal300K-40K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# /Users/alexisdevitre/Desktop/IcT/f29/before800keV/Ic_2024-02-26_13-51-45584459_f29-6e20pm2-anneal300K-30K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# /Users/alexisdevitre/Desktop/IcT/f29/before800keV/Ic_2024-02-26_14-09-04359114_f29-6e20pm2-anneal300K-40K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# [-1.58589258e-02  4.93136730e-01 -8.07834468e+00  7.65048978e+01] 0.014887563793429977 13.100123122048142

# %%
tape = 'f29'
fitfunction = hts.poly4
paths = [
    '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, '6e20pm2'),
    '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, 'after800keV'),
    '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, 'after2400keV')    
]
fig, ax = plt.subplots(figsize=(9,4))

for path, c in zip(paths, ['k', 'b', 'r']):
    fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
    _, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

    popt, pcov = curve_fit(fitfunction, ic, temperature)
    xsmooth = np.linspace(0, 8, 10000)
    ysmooth = fitfunction(xsmooth, *popt)

    ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color=c)
    ax.plot(ic, temperature, linestyle='None', marker='+', color=c)

ax.set_title('COMPARE: 6e20pm2, after800keV, after2400keV')

ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
#ax.set_xlim(2, 5)
#ax.set_ylim(0, 60)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [ 0.10292205 -0.34163425 -8.87961175 54.92738009] 2.2988728881138933 4.1049993294418545

# %%
tape, interpolation = 'f37', '0e20pm2'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)
ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

fnames = [
    'Ic_2024-03-15_15-33-11541053_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-33-11541053_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-33-11541053_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-39-26887224_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-41-36899237_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-44-10189824_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-47-59177530_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-49-55985361_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_15-52-03224088_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-01-48984464_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-05-41020332_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-06-50058800_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-07-59005907_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-14-02203597_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-15-38989035_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-18-23596236_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-19-43575662_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-25-13317419_f37-6p3e19pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-28-12934696_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-30-25405703_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-32-19051175_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-33-26046441_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-35-15440883_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_17-36-21940596_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_18-45-44322019_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_18-47-33311253_f37-1p8e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_18-56-13893809_f37-1p98e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-17-53274191_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-21-55030294_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-24-17851815_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-26-04611575_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-27-47592950_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-30-13867213_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-32-00001413_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-33-26319114_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-35-04191065_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-36-46228479_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-38-20899811_f37-3e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_19-58-35973867_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_20-00-36570011_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_20-04-18173442_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_20-05-41148687_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_20-07-39152234_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_21-12-29057491_f37-4e20pm2-1200keV0nA-20k.txt',
    'Ic_2024-03-15_21-14-55568130_f37-4e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_21-16-29534431_f37-4e20pm2-1200keV-0nA-20k.txt'
]
path, tHTS, ics = '../data/Ic/{}/'.format(tape), [], []
for fpath in [path+f for f in fnames]:
    try:
        ic, _, _, _, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function=hts.powerLaw, vMax=5e-6, vb=False)
        _, _, temperature = hts.readIV(fpath)
        tHTS.append(np.nanmean(temperature[0][-10:]))
        ics.append(ic)
    except Exception as e:
        pass
ax.plot(ics, tHTS, marker='o', color='k', linestyle='None')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 40)
ax.set_ylim(0, 100)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# readIV raised:  Some errors were detected !
#     Line #36 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f37/0e20pm2/Ic_2024-03-15_12-43-19987521_f37-0e0pm2-40k.txt cannot access local variable 'current' where it is not associated with a value
# [-6.30378498e-04  6.00076662e-02 -3.19757930e+00  8.51455499e+01] 13.671099946385251 13.671099946385251

# %%
tape, interpolation = 'f37', '6e20pm2'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

fnames = [
    'Ic_2024-03-15_23-37-40032783_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-39-01850600_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-40-07822052_f37-6e20pm2-1200keV-0nA-20k.txt',
    
    'Ic_2024-03-15_23-41-01862537_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-42-04545560_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-43-15578270_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-30-51525536_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-35-24613873_f37-6e20pm2-1200keV-0nA-20k.txt',
    
    'Ic_2024-03-18_10-37-36023050_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-43-04013771_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-44-16008861_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-45-43615717_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-46-59181881_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-49-09029546_f37-6e20pm2-1200keV-0nA-20k.txt'
    
]
path, tHTS, ics = '../data/Ic/{}/'.format(tape), [], []
for fpath in [path+f for f in fnames]:
    try:
        ic, _, _, _, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function=hts.powerLaw, vMax=5e-6, vb=False)
        _, _, temperature = hts.readIV(fpath)
        tHTS.append(np.nanmean(temperature[0][-10:]))
        ics.append(ic)
    except Exception as e:
        pass
ax.plot(ics, tHTS, marker='o', color='k', linestyle='None')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 7)
ax.set_ylim(0, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# readIV raised:  Some errors were detected !
#     Line #68 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f37/6e20pm2/Ic_2024-03-17_17-03-10605768_f37-6e20pm2-1200keV-0nA-27k.txt cannot access local variable 'current' where it is not associated with a value
# [-2.81768884e-02  8.24141336e-01 -1.13586653e+01  6.67416650e+01] 6.38754115790026 6.38754115790026

# %%
tape = 'f28'
paths = [
    '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, '0e20pm2'),
    '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, '6e20pm2')
]
fig, ax = plt.subplots(figsize=(9,4))

for path, c, fitfunction in zip(paths, ['k', 'b'], [hts.poly3, hts.poly4]):
    fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
    _, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

    popt, pcov = curve_fit(fitfunction, ic, temperature)
    xsmooth = np.linspace(0, 100, 10000)
    ysmooth = fitfunction(xsmooth, *popt)

    ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color=c)
    ax.plot(ic, temperature, linestyle='None', marker='+', color=c)

ax.set_title('COMPARE: 0e20pm2 and 6e20pm2')

ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 40)
ax.set_ylim(0, 100)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# readIV raised:  Some errors were detected !
#     Line #43 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f28/0e20pm2/Ic_2024-03-08_08-48-17476264_f28-0e0pm2-40k.txt cannot access local variable 'current' where it is not associated with a value
# /Users/alexisdevitre/Desktop/IcT/f28/6e20pm2/Ic_2024-03-12_18-58-55310893_f28-6e20pm2-1200keV-0nA-30k.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# [ -0.09208963   1.76428597 -16.21867323  62.45135667] 0.8608147394584271 4.014656080952058

# %%
tape, interpolation = 'f33', '800keV-1'
fitfunction = hts.linear
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)
ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

fnames = [
    'Ic_2023-12-20_15-44-20508092_f33-800keV-0nA-20K.txt'
    
]
path, tHTS, ics = '../data/Ic/{}/'.format(tape), [], []
for fpath in [path+f for f in fnames]:
    try:
        ic, _, _, _, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function=hts.powerLaw, vMax=5e-6, vb=False)
        _, _, temperature = hts.readIV(fpath)
        tHTS.append(np.nanmean(temperature[0][-10:]))
        ics.append(ic)
    except Exception as e:
        pass
ax.plot(ics, tHTS, marker='o', color='k', linestyle='None')




ax.set_title('Sample {}, {}\n{:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(4.2, 5)
ax.set_ylim(18, 23)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-5.78670857 48.23682829] 4.981136075446584 4.981136075446584

# %%
tape, interpolation = 'f33', '150keV-2'
fitfunction = hts.poly3
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.4f}x2 + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(4, 5)
ax.set_ylim(18, 22)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# /Users/alexisdevitre/Desktop/IcT/f33/150keV-2/Ic_2023-12-20_19-16-09461493_f33-150keV-0nA-20p5K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# [  2.33241877 -26.30747764  91.4589443 ] 4.338675132185235 4.616093417587057

# %%
tape, interpolation = 'f33', '800keV-2'
fitfunction = hts.linear
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(4, 4.4)
ax.set_ylim(18, 22)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-6.36606775 47.15088166] 4.062279195355733 4.293423815922183

# %%
tape, interpolation = 'f33', '2400keV-1'
fitfunction = hts.linear
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(4.4, 4.8)
ax.set_ylim(18, 22)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-5.1140279  43.92643594] 4.468969242319102 4.70714425754863

# %%
tape, interpolation = 'f33', '2400keV-2'
fitfunction = hts.linear
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(4, 4.4)
ax.set_ylim(18, 22)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-5.19772732 42.0964148 ] 4.087282945240514 4.2494061049134215

# %%
tape, interpolation = 'f37', 'before150keVSet'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 30, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2f}x + {:4.2f}x + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 15)
ax.set_ylim(18, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# readIV raised:  invalid index to scalar variable.
# /Users/alexisdevitre/Desktop/IcT/f37/before150keVSet/Ic_2024-05-12_02-40-43219450_f37-anneal300K256h-773K.txt cannot access local variable 'temperature' where it is not associated with a value
# readIV raised:  not enough values to unpack (expected 4, got 0)
# /Users/alexisdevitre/Desktop/IcT/f37/before150keVSet/Ic_2024-05-12_02-41-17625286_f37-anneal300K256h-773K.txt cannot access local variable 'current' where it is not associated with a value
# readIV raised:  invalid index to scalar variable.
# /Users/alexisdevitre/Desktop/IcT/f37/before150keVSet/Ic_2024-05-12_02-40-41496177_f37-anneal300K256h-773K.txt cannot access local variable 'temperature' where it is not associated with a value
# [-1.07515002e-02  3.91599223e-01 -7.61459952e+00  7.51566262e+01] 0.012276930208627718 12.677955855103725
# ...

# %%
tape, interpolation = 'f37', 'after150keVSet'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 30, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2f}x + {:4.2f}x + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 15)
ax.set_ylim(18, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# /Users/alexisdevitre/Desktop/IcT/f37/after150keVSet/Ic_2024-05-12_20-15-15711816_f37-beamOnSet1-30K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# [-7.40832522e-03  3.21353725e-01 -7.19257139e+00  7.44367362e+01] 0.5154968522270051 12.672227048341002

# %%
tape, interpolation = 'f37', 'after2400keVSet'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 30, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

ax.set_title('Sample {}, {}\n{:4.2f}x + {:4.2f}x + {:4.2f}x + {:4.2f}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 15)
ax.set_ylim(18, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))
# Out:
# <img src="data:image/png;base64,..." width="900">
# [-6.33577596e-03  2.92577388e-01 -6.99641227e+00  7.34218387e+01] 0.5930487166916827 12.301540754852565

# %%
fig, ax = plt.subplots(2, 1, gridspec_kw={'height_ratios': [3, 1]})

files = [
    'Ic_2024-03-01_16-55-21091441_f29-2400keV-0nA-20k.txt',
    'Ic_2024-03-01_16-39-59692871_f29-2400keV-0nA-20k.txt',
    'Ic_2024-03-01_16-24-36385084_f29-2400keV-0nA-20k.txt'
]

fpaths = ['../data/Ic/f29/'+f for f in files]

for fpath, c in zip(fpaths, sns.color_palette('viridis', len(fpaths))):
    
    current, voltage, sampleT = hts.readIV(fpath)
    xsmooth = np.linspace(np.min(current), np.max(current), 10000)
    popt, pcov, chisq = hts.fitIV(current, voltage)

    ax[0].plot(xsmooth, 1e6*hts.powerLaw(xsmooth, *popt), color=c, linewidth=4, alpha=.3)
    ax[0].plot(current, 1e6*voltage, label=fpath.split('_')[-1], color=c, marker='+')
    ax[0].set_title(fpath.split('_')[-1])

    r = 1e6*(hts.powerLaw(current, *popt)-voltage)

    ax[1].plot(current, 1e6*(hts.powerLaw(current, *popt)-voltage), marker='+', linestyle='None', color=c)
ax[0].axhline()
ax[0].axhline(0.2, color='k', linestyle='--')
ax[0].set_ylim(-.2, .4)
# Out:
# <img src="data:image/png;base64,..." width="800">
# (-0.2, 0.4)

# %% [markdown]
# ## FFJ37 0e20 p/m$^2$ vs 6e20 p/m$^2$

# %%
fig, ax = plt.subplots(figsize=(9,4))
fitfunction = hts.poly4


tape, interpolation = 'f37', '0e20pm2'
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic0, temperature0, _ = hts.getIcT(fpaths, vb=False)
popt, pcov = curve_fit(fitfunction, ic0, temperature0)
xsmooth = np.linspace(0, 8, 10000)
ysmooth = fitfunction(xsmooth, *popt)
ax.plot(xsmooth/5, ysmooth/88.45, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(np.array(ic0)/5, np.array(temperature0)/88.45, linestyle='None', marker='+', color='b')


tape, interpolation = 'f37', '6e20pm2'
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic1, temperature1, _ = hts.getIcT(fpaths, vb=False)
popt, pcov = curve_fit(fitfunction, ic1, temperature1)
xsmooth = np.linspace(0, 8, 10000)
ysmooth = fitfunction(xsmooth, *popt)
ax.plot(xsmooth, ysmooth/73.5, linestyle='-', linewidth=4, alpha=.3, color='r')
ax.plot(ic1, np.array(temperature1)/73.5, linestyle='None', marker='+', color='r')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt), fontsize=12)
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')

fig.tight_layout()


upperbound = np.min([np.max(temperature0), np.max(temperature1)])
lowerbound = np.max([np.min(temperature0), np.min(temperature1)])
#ax.set_xlim(0, 40)
#ax.set_ylim(lowerbound, upperbound)
# Out:
# <img src="data:image/png;base64,..." width="900">
# readIV raised:  Some errors were detected !
#     Line #36 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f37/0e20pm2/Ic_2024-03-15_12-43-19987521_f37-0e0pm2-40k.txt cannot access local variable 'current' where it is not associated with a value
# readIV raised:  Some errors were detected !
#     Line #68 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f37/6e20pm2/Ic_2024-03-17_17-03-10605768_f37-6e20pm2-1200keV-0nA-27k.txt cannot access local variable 'current' where it is not associated with a value

# %% [markdown]
# ## FFJ37 150 and 2400 keV sets

# %%
tape, interpolation = 'f37', '6e20pm2'
fitfunction = hts.poly4
path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
fig, ax = plt.subplots(figsize=(9,4))

fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
_, _, ic, temperature, _ = hts.getIcT(fpaths, vb=False)

popt, pcov = curve_fit(fitfunction, ic, temperature)
xsmooth = np.linspace(0, 100, 10000)
ysmooth = fitfunction(xsmooth, *popt)

ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color='b')
ax.plot(ic, temperature, linestyle='None', marker='+', color='k')

fnames = [
    'Ic_2024-03-15_23-37-40032783_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-39-01850600_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-40-07822052_f37-6e20pm2-1200keV-0nA-20k.txt',
    
    'Ic_2024-03-15_23-41-01862537_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-42-04545560_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-15_23-43-15578270_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-30-51525536_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-35-24613873_f37-6e20pm2-1200keV-0nA-20k.txt',
    
    'Ic_2024-03-18_10-37-36023050_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-43-04013771_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-44-16008861_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-45-43615717_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-46-59181881_f37-6e20pm2-1200keV-0nA-20k.txt',
    'Ic_2024-03-18_10-49-09029546_f37-6e20pm2-1200keV-0nA-20k.txt'
    
]
path, tHTS, ics = '../data/Ic/{}/'.format(tape), [], []
for fpath in [path+f for f in fnames]:
    try:
        ic, _, _, _, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function=hts.powerLaw, vMax=5e-6, vb=False)
        _, _, temperature = hts.readIV(fpath)
        tHTS.append(np.nanmean(temperature[0][-10:]))
        ics.append(ic)
    except Exception as e:
        pass
ax.plot(ics, tHTS, marker='o', color='k', linestyle='None')

ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt))
ax.set_xlabel('$\mathrm{I_c}$ [A]')
ax.set_ylabel('Temperature [K]')
ax.set_xlim(0, 7)
ax.set_ylim(0, 80)
fig.tight_layout()

print(popt, np.min(ic), np.max(ic))

# %%
fig, ax = plt.subplots(figsize=(6,6))
fitfunction = ff.linear

######################################################################
######################################################################
######################################################################
######################################################################
######################################################################
######################################################################
tape = 'f29'

alpha, degradation = [], []
for interpolation, c in zip(['0e20pm2', '6e20pm2', 'after800keV', 'after2400keV'], ['b', 'r', 'k', 'orange']):

    path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
    fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
    _, _, ics, temperatures, _ = hts.getIcT(fpaths, vb=False)
    
    x, y = np.array(temperatures), np.array(ics)
    cut = (19 <= x) & (x <= 29)
    x, y = x[cut], y[cut]
    
    popt, pcov = curve_fit(fitfunction, x, y)
    xsmooth = np.linspace(19, 29, 10000)
    ysmooth = fitfunction(xsmooth, *popt)
    
    ic20k = np.max(y)#ysmooth[np.argmin(np.abs(ysmooth-20))]
    
    ax.plot(xsmooth, ysmooth/ic20k, linestyle='-', linewidth=4, alpha=.3, color=c, label=interpolation+' {:4.4f}'.format(popt[0]))
    ax.plot(x, y/ic20k, linestyle='None', marker='+', color=c)
    
    degradation.append(ic20k/33.07)
    alpha.append(popt[0]/ic20k)
    
#ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt), fontsize=12)
ax.set_ylabel('$\mathrm{I_c}$ [A]')
ax.set_xlabel('Temperature [K]')
ax.legend()
fig.tight_layout()

alpha29, degradation29 = np.array(alpha), np.array(degradation)

upperbound = np.min([np.max(temperature0), np.max(temperature1)])
lowerbound = np.max([np.min(temperature0), np.min(temperature1)])
ax.set_ylim(.65, 1.1)
ax.set_xlim(18, 30)
# Out:
# <img src="data:image/png;base64,..." width="600">
# /Users/alexisdevitre/Desktop/IcT/f29/0e20pm2/Ic_2024-02-06_10-02-15263819_f29-pristine-64K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# (18.0, 30.0)

# %% [markdown]
# ## f37 slope of Ic(T) as a function of degradation

# %%
from scipy.interpolate import interp1d
from scipy.optimize import brentq

def invert(ic, popt):
    def f(x):
        return popt[0]*(x-20)**3 + popt[1]*(x-20)**2 + popt[2]*(x-20) + 1 - ic
    return brentq(f, 20, 80)
# Out:
# 44.29357534579022

# %%
fig, ax = plt.subplots(figsize=(6,6))
fitfunction = ff.cubic2

######################################################################
######################################################################
######################################################################
######################################################################
######################################################################
######################################################################
tape = 'f37'
alpha, degradation = [], []
for interpolation, c in zip(['0e20pm2', '6e20pm2', 'after150keVSet', 'after2400keVSet'], ['b', 'r', 'g', 'k']):

    path = '/Users/alexisdevitre/Desktop/IcT/{}/{}/'.format(tape, interpolation)
    fpaths = [path+f for f in os.listdir(path) if (f != '.DS_Store')]
    _, _, ics, temperatures, _ = hts.getIcT(fpaths, vb=False)
    
    ic20k = np.max(ics)
    if interpolation == '0e20pm2':
        ic0_20k = ic20k
    x, y = np.array(temperatures), np.array(ics)/ic20k
    #cut = (19 <= x) & (x <= 29)
    #x, y = x[cut], y[cut]
    
    popt, pcov = curve_fit(fitfunction, x, y)
    xsmooth = np.linspace(20, 80, 10000)
    ysmooth = fitfunction(xsmooth, *popt)
    
    ax.plot(xsmooth, ysmooth, linestyle='-', linewidth=4, alpha=.3, color=c, label=interpolation+' {:4.4f}'.format(popt[0]))
    ax.plot(x, y, linestyle='None', marker='+', color=c)
    
    degradation.append(ic20k/ic0_20k)
    alpha.append(popt[0]/ic20k)
    
    if interpolation == '0e20pm2':
        #popt, pcov = curve_fit(fitfunction, y, x)
        popt_blue = popt #popt #interp1d(ysmooth/ic20k, xsmooth)
        print(popt)
    if interpolation == '6e20pm2':
        popt_red = popt #popt #interp1d(ysmooth/ic20k, xsmooth)
    
    if interpolation == 'after150keVSet':
        Icgreen = ysmooth

desired = degradation[2]
x = (desired-degradation[1])/(degradation[0]-degradation[1])
#x = degradation[2]/(degradation[0]+degradation[1])
ics = np.linspace(0.1, 1, 10)

Tgreen, Tblue, Tred = np.array([]), np.array([]), np.array([])
for ic in ics:
    r, b = invert(ic, popt_red), invert(ic, popt_blue)
    g = r + (b - r)*x
    Tblue = np.append(Tblue, b)
    Tred = np.append(Tred, r)
    Tgreen = np.append(Tgreen, g)

#Tgreen = fitfunction(IcGreen, *Tred) + (fitfunction(IcGreen, *Tblue)-fitfunction(IcGreen, *Tred))*x

ax.plot(Tgreen, ics, marker='o', markersize=5, linestyle='None')

for ic, g, a in zip(ics, Tgreen, (Tblue+Tred)/2):
    print('{:4.4f}'.format(ic), '{:4.4f}'.format(g), '{:4.4f}'.format(a))

#ax.set_title('Sample {}, {}\n{:4.2e}x3 + {:4.2e}x2 + {:4.2e}x + {:4.2e}'.format(tape, interpolation, *popt), fontsize=12)
ax.set_ylabel('$\mathrm{I_c}$ [A]')
ax.set_xlabel('Temperature [K]')
ax.legend()
fig.tight_layout()

alpha37, degradation37 = np.array(alpha), np.array(degradation)

upperbound = np.min([np.max(temperature0), np.max(temperature1)])
lowerbound = np.max([np.min(temperature0), np.min(temperature1)])
ax.set_ylim(0, 1.1)
ax.set_xlim(18, 80)
# Out:
# <img src="data:image/png;base64,..." width="600">
# [-3.88998965e-07  1.66203890e-04 -2.43896814e-02]
# readIV raised:  Some errors were detected !
#     Line #68 (got 5 columns instead of 4)
# /Users/alexisdevitre/Desktop/IcT/f37/6e20pm2/Ic_2024-03-17_17-03-10605768_f37-6e20pm2-1200keV-0nA-27k.txt zero-size array to reduction operation maximum which has no identity
# /Users/alexisdevitre/Desktop/IcT/f37/after150keVSet/Ic_2024-05-12_20-15-15711816_f37-beamOnSet1-30K.txt Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[171], line 60
#      56 #Tgreen = fitfunction(IcGreen, *Tred) + (fitfunction(IcGreen, *Tblue)-fitfunction(IcGreen, *Tred))*x
#      58 ax.plot(Tgreen, ics, marker='o', markersize=5, linestyle='None')
# ---> 60 for ic, g, a in zip(ics, Tgreen, (Tblue+Tred)/2):
# ...

# %%
Tgreen, degradation
# Out:
# (array([66.94623965, 65.56534056, 64.20292888, 62.85896008, 61.53338965,
#         60.22617308, 58.93726583, 57.6666234 , 56.41420125, 55.17995488,
#         53.96383976, 52.76581138, 51.58582521, 50.42383673, 49.27980143,
#         48.15367478, 47.04541227, 45.95496938, 44.88230159, 43.82736437,
#         42.79011321, 41.77050359, 40.76849099, 39.78403089, 38.81707877,
#         37.86759012, 36.9355204 , 36.02082511, 35.12345972, 34.24337972,
#         33.38054058, 32.53489778, 31.70640681, 30.89502315, 30.10070227,
#         29.32339966, 28.5630708 , 27.81967117, 27.09315624, 26.38348151,
#         25.69060245, 25.01447453, 24.35505325, 23.71229408, 23.08615251,
#         22.476584  , 21.88354405, 21.30698814, 20.74687174, 20.20315033]),
#  [1.0, 0.18657000907933957, 0.36188144728815574, 0.35129573951431664])

# %%
fig, ax = plt.subplots()

x, y = np.append(degradation29, degradation37), np.append(alpha29, alpha37)
cut = y < 0
x, y = x[cut], y[cut]

popt, pcov = curve_fit(ff.linear, x, y)
xsmooth= np.linspace(0, 1, 1000)
ysmooth = ff.linear(xsmooth, *popt)

ax.plot(degradation29, alpha29, marker='o', linestyle='None')
ax.plot(degradation37, alpha37, marker='s', linestyle='None')

ax.plot(xsmooth, ysmooth, linewidth=4, color='lightgray', alpha=.5)
popt
# Out:
# <img src="data:image/png;base64,..." width="800">
# array([ 0.01142512, -0.03347866])

# %%
fig, ax = plt.subplots()
path = '/Users/alexisdevitre/Documents/GitHub/2024-Beam-On-Not/data/Ic/f33/'
files = [
    'Ic_2023-12-20_17-50-41269138_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-52-23031643_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-53-32055512_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-55-01975085_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-55-51092338_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-56-53973896_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_17-59-44745475_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_18-00-37480538_f33-2400keV-11nA-20K.txt',
    'Ic_2023-12-20_18-01-43254457_f33-2400keV-11nA-20K.txt'
]
for fpath in [path+f for f in files]:
    #hts.readIV(fpath)
    ic, n, current, voltage, _, _ = hts.fitIcMeasurement(fpath, fformat='mit', function='powerLaw', vMax=5e-6, vb=False)
    ax.plot(current, voltage)
    print(ic)
# Out:
# <img src="data:image/png;base64,..." width="800">
# 4.701874885491664
# 4.741742350245049
# 4.667354458434968
# 4.706526685358395
# 4.646139002958818
# 4.700711014667377
# 4.700902278063842
# 4.726239712703979
# 4.753603077931245
